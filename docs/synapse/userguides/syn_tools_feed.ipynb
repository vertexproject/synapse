# %% [raw]
# .. highlight:: none
#
# .. _syn-tools-feed:
#
# Synapse Tools - feed
# ====================
#
# The Synapse ``feed`` command can be used to ingest structured data into a Cortex to create nodes, set properties, and / or apply tags. ``feed`` accepts input in JSON, yaml, or msgpack format. (For CSV-formatted data, see :ref:`syn-tools-csvtool`.)
#
# Syntax
# ------
#
# ``feed`` is executed from an operating system command shell. The command usage is as follows:
#
# ::
#
#   usage: synapse.tools.feed [-h] (--cortex CORTEX | --test) [--debug]
#                             [--format FORMAT] [--modules MODULES]
#                             [--chunksize CHUNKSIZE] [--offset OFFSET]
#                             [files [files ...]]
#
#   Command line tool for ingesting data into a cortex
#
#   positional arguments:
#     files                 json/yaml/msgpack feed files
#
#   optional arguments:
#     -h, --help            show this help message and exit
#     --cortex CORTEX, -c CORTEX
#                           Cortex to connect and add nodes too.
#     --test, -t            Perform a local ingest against a temporary cortex.
#     --debug, -d           Drop to interactive prompt to inspect cortex after
#                           loading data.
#     --format FORMAT, -f FORMAT
#                           Feed format to use for the ingested data.
#     --modules MODULES, -m MODULES
#                           Additional modules to load locally with a test Cortex.
#     --chunksize CHUNKSIZE
#                           Default chunksize for iterating over items.
#     --offset OFFSET       Item offset to start consuming msgpack files from.
#
# Where:
#
# - ``files`` is the name / path of the file (or files) to ingest.
# - ``CORTEX`` specifies the path to the Cortex where the data should be ingested.
#
#   - See :ref:`cortex-connect` for the format to specify a path to a Cortex.
#   - Cortex paths can also be specified using aliases defined in the user's ``.syn/aliases.yaml`` file.
#
# - ``--test`` specifies the data should be loaded into a temporary local Cortex (i.e., for testing / validation).
#
#   - When using a temporary Cortex, you do not need to provide a path.
#
# - ``--debug`` sends verbose output to ``stdout`` during execution **and** opens a ``cmdr`` (see :ref:`syn-tools-cmdr`) command prompt to the specified Cortex after ``feed`` exits.
#
#   - The command prompt will be connected to the Cortex specified by the ``--cortex CORTEX`` or ``--test`` option.
#
# - ``FORMAT`` is the format of the ingest file.
#
#   - If no format is specified, ``feed`` assumes the default format (JSON).
#
# Example
# -------
#
# TBD
